# %%
import glob
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('dataset/2015.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
plt.figure(figsize=(12, 12))
df_corr = df.corr()
sns.heatmap(df_corr, cmap=sns.diverging_palette(220, 20, n=12), annot=True)
plt.title("Correlation")
plt.show()

# %%
X = np.array(df[['Economy (GDP per Capita)' , 'Family' , 'Health (Life Expectancy)' , 'Freedom' , 'Trust (Government Corruption)' , 'Generosity' , 'Dystopia Residual']])
y = np.array(df[['Happiness Score']])

# %%
m = y.size

# %%
print('The shape of the X is {}'.format(X.shape))
print('The shape of the y is {}'.format(y.shape))
# Out:
# The shape of the X is (158, 7)
# The shape of the y is (158, 1)

# %%
x_values = df.columns[5:-1]

# %%
for each in x_values:
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x = df['Happiness Score'] , y = df[each] , marker = '*' , s = 150 )
    plt.xlabel('Happiness Score')
    plt.ylabel(each)
    plt.show()

# %%
def normalization(X):
    
    standard_diviation = np.std(X , axis = 0)
    
    mean = np.mean(X, axis = 0)
    
    X_normalized = (X - mean) / standard_diviation
    
    return X_normalized

# %%
X = normalization(X)

# %%
X = np.concatenate([np.ones(m).reshape(m , 1) , X] , axis  = 1)
y = y.reshape(m , )

# %%
print('The shape of the X is {}'.format(X.shape))
print('The shape of the y is {}'.format(y.shape))
# Out:
# The shape of the X is (158, 8)
# The shape of the y is (158,)

# %%
def cost_function(X , y , theta):
    
    
    m = X.size
    
    J = 0
    
    h = np.dot(X , theta)
    
    J = 1 / (2 * m) * (np.sum(np.square(h - y))) 
    
    return J

# %%
theta = np.zeros(8)
J = cost_function(X , y , theta)

# %%
print('The value of the cost function with these {} theta is {:.2f} .'.format(theta , J))
# Out:
# The value of the cost function with these [0. 0. 0. 0. 0. 0. 0. 0.] theta is 1.89 .

# %%
def gradian_decent(X , y , theta , alpha , iteration):
    
    m = X.size 
    
    theta = theta.copy()
    
    Jz = []
    
    thetaz = []
    
    for i in range(iteration):
        
        theta = theta - ( alpha / m ) *  ( np.dot( X , theta ) - y ).dot( X )
        
        thetaz.append(theta)
        
        Jz.append(cost_function(X , y , theta))
        
        
    minimized_J = Jz[-1]
    
    best_thetas = thetaz[-1]
    
    return minimized_J , best_thetas , Jz

# %%
theta = np.zeros(8)
alpha = .02
iteration = 2000

# %%
minimized_J , best_thetas , Jz = gradian_decent(X , y , theta , alpha , iteration)

# %%
print("Theta found by gradient descent: {}".format(best_thetas))
print("Final cost value:  {:0.10f}".format(minimized_J))
# Out:
# Theta found by gradient descent: [5.33973882 0.35668338 0.28657586 0.27622543 0.15848556 0.12228793
#  0.11165008 0.54393663]
# Final cost value:  0.0001197017

# %%
best_thetas
# Out:
# array([5.33973882, 0.35668338, 0.28657586, 0.27622543, 0.15848556,
#        0.12228793, 0.11165008, 0.54393663])

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(x = range(iteration) , y = Jz)
plt.xlabel('Iteration')
plt.ylabel('Cost Fucntion Val')
plt.show()
